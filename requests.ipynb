# %%
import requests

resp = requests.get("http://xlzd.me")

resp.status_code
# Out:
# 200

# %%
发送一个完整的http请求

# %%
import requests

r = requests.post("http://xlzd.me/login",data = {"user":"xlzd","password":"mypassword"})

r = requests.put("http://xlzd.me/posrt",data = {"title":"article"})

r = requests.delete("http://xlzd.me/foo")

r = requests.head("http://xlzd.me/bar")

r = requests.options("http://xlzd.me/abc")

# %%
解析URL参数

# %%
r = requests.get("http://xlzd.me/query",params = {"name":"xlzd","lang":"python"})

print(r.url)
# Out:
# http://xlzd.me/query?name=xlzd&lang=python

# %%
字典中的参数会被自动解析并且正确的链接URL中

# %%
响应内容

# %%
r = requests.get("http://xlzd.me")

r.encoding
# Out:
# 'UTF-8'

# %%
r.headers
# Out:
# {'X-Powered-By': 'PHP/5.4.45', 'X-Pingback': 'http://xlzd.me/action/xmlrpc', 'Vary': 'Accept-Encoding', 'Connection': 'keep-alive', 'Date': 'Tue, 30 Aug 2016 10:33:12 GMT', 'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=UTF-8', 'Server': 'nginx'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="zh-CN">\n\t<head>\n<meta name="google-site-verification" content="wRTsQbQJP49HbdD4B--2EAK4PDk5ifuapS8JeUh-Fdc" />\n\t<meta charset="UTF-8">\n    \t<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\n    \t<meta name="renderer" content="webkit">\n    \t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n    \t<title>xlzd杂谈</title>\n                <link rel="Shortcut Icon" href="http://7xkpi6.com1.z0.glb.clouddn.com/avatar.png" />\n        <link rel="Bootmark" href="http://7xkpi6.com1.z0.glb.clouddn.com/avatar.png" />\n                <meta name="description" content="技术宅，专栏作者，软件工程师" />\n<meta name="keywords" content="xlzd,duxu,blog,Python,编程,博客,技术,Android" />\n<meta name="generator" content="Typecho 1.0/14.10.10" />\n<meta name="template" content="material" />\n<link rel="pingback" href="http://xlzd.me/action/xmlrpc" />\n<link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://xlzd.me/action/
# ...

# %%
r.content
# Out:
# b'<!DOCTYPE HTML>\n<html lang="zh-CN">\n\t<head>\n<meta name="google-site-verification" content="wRTsQbQJP49HbdD4B--2EAK4PDk5ifuapS8JeUh-Fdc" />\n\t<meta charset="UTF-8">\n    \t<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\n    \t<meta name="renderer" content="webkit">\n    \t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n    \t<title>xlzd\xe6\x9d\x82\xe8\xb0\x88</title>\n                <link rel="Shortcut Icon" href="http://7xkpi6.com1.z0.glb.clouddn.com/avatar.png" />\n        <link rel="Bootmark" href="http://7xkpi6.com1.z0.glb.clouddn.com/avatar.png" />\n                <meta name="description" content="\xe6\x8a\x80\xe6\x9c\xaf\xe5\xae\x85\xef\xbc\x8c\xe4\xb8\x93\xe6\xa0\x8f\xe4\xbd\x9c\xe8\x80\x85\xef\xbc\x8c\xe8\xbd\xaf\xe4\xbb\xb6\xe5\xb7\xa5\xe7\xa8\x8b\xe5\xb8\x88" />\n<meta name="keywords" content="xlzd,duxu,blog,Python,\xe7\xbc\x96\xe7\xa8\x8b,\xe5\x8d\x9a\xe5\xae\xa2,\xe6\x8a\x80\xe6\x9c\xaf,Android" />\n<meta na
# ...

# %%
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
自定义header

# %%
模拟浏览器发送请求,伪装header

# %%
url = "http://xlzd.me"

headers = {"User-Agent":"my custom user agent","cookies":"haha"}

requests.get(url,headers = headers)
# Out:
# <Response [200]>

# %%
重定向和超时

# %%
r = requests.get("http://xlzd.me",allow_redirects = False)

# %%
allow_redirects = False false是不会重定向

# %%
超时

# %%
r = requests.get

# %%
代理

# %%
import requests

proxies = {
    "http": "http://192.168.31.1:3128",
    "https": "http://10.10.1.10:1080",
}

requests.get("http://xlzd.me", proxies=proxies)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Users\ricaito\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     136             conn = connection.create_connection(
# --> 137                 (self.host, self.port), self.timeout, **extra_kw)
#     138
#
# D:\Users\ricaito\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      90     if err is not None:
# ---> 91         raise err
#      92
#
# D:\Users\ricaito\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      80                 sock.bind(source_address)
# ---> 81             sock.connect(sa)
#      82             return sock
#
# ...

# %%
会话对象

服务器端通过session来区分不同的用户请求（浏览器会话），

requests的会话对象是用来模拟这样的操作的，

比如可以跨请求保持某些参数：就像你在访问微博的时候，不需要每次翻页都重新登录一次。

# %%
session = requests.Session()

session.post("http://xlzd.me/login",data = {'user':'xlzd','pass':'mypassword'})

session.put("http://xlzd.me/new",data = {'title': 'title of article', 'data': 'content'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9443bdc1a26c> in <module>()
# ----> 1 session = requests.Session()
#       2
#       3 session.post("http://xlzd.me/login",data = {'user':'xlzd','pass':'mypassword'})
#       4
#       5 session.put("http://xlzd.me/new",data = {'title': 'title of article', 'data': 'content'})
#
# NameError: name 'requests' is not defined
